# %% [markdown]
# ## Importing Libraries

# %%
## importing the python libarary
import pandas as pd 
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
## uploading the csv file
df=pd.read_csv("airline_passenger_satisfaction.csv")

# %% [markdown]
# ## Data Info

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df.tail()
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 129875              447                2            3.0
# 129876              308                0            0.0
# 129877              337                6           14.0
# 129878              337               31           22.0
# 129879              337                0            0.0
#
#         Departure and Arrival Time Convenience  ...  On-board Service  \
# 129875                                       4  ...                 5
# ...

# %%
df.shape
# Out:
# (129880, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %%
df.dtypes
# Out:
# ID                                          int64
# Gender                                     object
# Age                                         int64
# Customer Type                              object
# Type of Travel                             object
# Class                                      object
# Flight Distance                             int64
# Departure Delay                             int64
# Arrival Delay                             float64
# Departure and Arrival Time Convenience      int64
# Ease of Online Booking                      int64
# Check-in Service                            int64
# Online Boarding                             int64
# Gate Location                               int64
# On-board Service                            int64
# Seat Comfort                                int64
# Leg Room Service                            int64
# Cleanliness                                 int64
# Food and Drink                              int64
# ...

# %% [markdown]
# ## Data Cleaning

# %%
## finding null values
df.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
## percentage of null values
df.isnull().sum()*100/len(df)
# Out:
# ID                                        0.000000
# Gender                                    0.000000
# Age                                       0.000000
# Customer Type                             0.000000
# Type of Travel                            0.000000
# Class                                     0.000000
# Flight Distance                           0.000000
# Departure Delay                           0.000000
# Arrival Delay                             0.302587
# Departure and Arrival Time Convenience    0.000000
# Ease of Online Booking                    0.000000
# Check-in Service                          0.000000
# Online Boarding                           0.000000
# Gate Location                             0.000000
# On-board Service                          0.000000
# Seat Comfort                              0.000000
# Leg Room Service                          0.000000
# Cleanliness                               0.000000
# ...

# %%
## dropping the null values
df1=df.dropna()

# %%
print(df1)
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
df1.isnull().sum()*100/len(df)
# Out:
# ID                                        0.0
# Gender                                    0.0
# Age                                       0.0
# Customer Type                             0.0
# Type of Travel                            0.0
# Class                                     0.0
# Flight Distance                           0.0
# Departure Delay                           0.0
# Arrival Delay                             0.0
# Departure and Arrival Time Convenience    0.0
# Ease of Online Booking                    0.0
# Check-in Service                          0.0
# Online Boarding                           0.0
# Gate Location                             0.0
# On-board Service                          0.0
# Seat Comfort                              0.0
# Leg Room Service                          0.0
# Cleanliness                               0.0
# Food and Drink                            0.0
# In-flight Service                         0.0
# ...

# %% [markdown]
# ## Finding Outliers

# %%
# Calculate IQR for 'Departure Delay'
Q1 = df['Departure Delay'].quantile(0.25)
Q3 = df['Departure Delay'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_departure = df[(df['Departure Delay'] < lower_bound) | (df['Departure Delay'] > upper_bound)]
print(f"Number of outliers in Departure Delay: {len(outliers_departure)}")

# Repeat for 'Arrival Delay'
Q1 = df['Arrival Delay'].quantile(0.25)
Q3 = df['Arrival Delay'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_arrival = df[(df['Arrival Delay'] < lower_bound) | (df['Arrival Delay'] > upper_bound)]
print(f"Number of outliers in Arrival Delay: {len(outliers_arrival)}")
# Out:
# Number of outliers in Departure Delay: 18098
# Number of outliers in Arrival Delay: 17492

# %% [markdown]
# ## Graphs

# %%
gender_counts = df['Gender'].value_counts()

# Create a pie chart
plt.figure(figsize=(5, 5))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=['green', 'orange'])
plt.title('Distribution of Passengers by Gender')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular
plt.show()

# %%
travel_counts = df['Type of Travel'].value_counts()

# Create a bar plot (histogram) for Type of Travel
plt.figure(figsize=(9, 5))
travel_counts.plot(kind='bar', color=['#66c2a5', '#fc8d62'])
plt.title('Distribution of Type of Travel')
plt.xlabel('Type of Travel')
plt.ylabel('Number of Passengers')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.show()

# %%
# Define a threshold for considering a flight as "canceled" based on departure delay
import matplotlib.pyplot as plt

cancellation_threshold = 180  # 180 minutes (3 hours)

# Determine if a flight is canceled
df['Canceled'] = (df['Departure Delay'] > cancellation_threshold) | (df['Arrival Delay'].isna())

# Count the number of canceled vs non-canceled flights
cancellation_counts = df['Canceled'].value_counts()

# Create a bar chart
plt.figure(figsize=(8, 6))
cancellation_counts.plot(kind='bar', color=['salmon', 'skyblue'], edgecolor='black')
plt.title('Flight Cancellations')
plt.xlabel('Flight Status')
plt.ylabel('Number of Flights')
plt.xticks(ticks=[0, 1], labels=['Non-Canceled', 'Canceled'], rotation=0)
plt.show()

# %%
# Creating  histograms for Departure Delay and Arrival Delay

import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))

# Departure Delay histogram
plt.subplot(1, 2, 1)
plt.hist(df['Departure Delay'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of Departure Delays')
plt.xlabel('Departure Delay (minutes)')
plt.ylabel('Frequency')

# Arrival Delay histogram
plt.subplot(1, 2, 2)
plt.hist(df['Arrival Delay'].dropna(), bins=30, color='salmon', edgecolor='black')
plt.title('Histogram of Arrival Delays')
plt.xlabel('Arrival Delay (minutes)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a scatter plot for Departure Delay vs Arrival Delay
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Departure Delay', y='Arrival Delay', data=df, alpha=0.6)
plt.title('Scatter Plot of Departure Delay vs Arrival Delay')
plt.xlabel('Departure Delay (minutes)')
plt.ylabel('Arrival Delay (minutes)')
plt.axhline(0, color='red', linestyle='--', linewidth=1)  # Horizontal line at y=0
plt.axvline(0, color='red', linestyle='--', linewidth=1)  # Vertical line at x=0
plt.show()

# %%
# Select relevant numerical columns for correlation
numeric_cols = ['Departure Delay', 'Arrival Delay', 'Flight Distance', 'In-flight Service', 
                'Food and Drink', 'Seat Comfort', 'Cleanliness']

# Calculate the correlation matrix
correlation_matrix = df[numeric_cols].corr()

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Heatmap of Correlation between Numerical Features')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('airline_passenger_satisfaction.csv')

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a box plot for In-flight Service ratings based on Satisfaction Level
plt.figure(figsize=(10, 5))
sns.boxplot(x='Satisfaction', y='In-flight Service', data=data)
plt.title('Box Plot of In-flight Service Ratings by Satisfaction Level')
plt.xlabel('Satisfaction Level')
plt.ylabel('In-flight Service Ratings')
plt.xticks(rotation=45)
plt.show()

# %%
# Count the occurrences of each satisfaction level
satisfaction_counts = data['Satisfaction'].value_counts()

# Create a pie chart
plt.figure(figsize=(5, 5))
plt.pie(satisfaction_counts, labels=satisfaction_counts.index, autopct='%1.1f%%', startangle=140, colors=['#66c2a5', '#fc8d62'])
plt.title('Distribution of Passenger Satisfaction Levels')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular
plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize = (15,5))
sns.boxplot(x = "Customer Type", y = "Age", palette = "YlOrBr", data = data, ax = ax[0])
sns.histplot(data, x = "Age", hue = "Customer Type", multiple = "stack", palette = "YlOrBr", edgecolor = ".3", linewidth = .5, ax = ax[1])
pass
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_45600\2067886324.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = "Customer Type", y = "Age", palette = "YlOrBr", data = data, ax = ax[0])

# %%
f, ax = plt.subplots(1, 2, figsize = (15,5))
sns.boxplot(x = "Class", y = "Flight Distance", palette = "YlOrBr", data = data, ax = ax[0])
sns.histplot(data, x = "Flight Distance", hue = "Class", multiple = "stack", palette = "YlOrBr", edgecolor = ".3", linewidth = .5, ax = ax[1])
pass
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_45600\251457757.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = "Class", y = "Flight Distance", palette = "YlOrBr", data = data, ax = ax[0])

# %%
# Univariate Analysis
# Age distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], kde=True, color='blue')
plt.title('Age Distribution')
plt.show()

# %%
# Satisfaction distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Satisfaction', data=df, palette='viridis')
plt.title('Satisfaction Levels Distribution')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_45600\427218514.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Satisfaction', data=df, palette='viridis')

# %%
# Flight Distance distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Flight Distance'], kde=True, color='green')
plt.title('Flight Distance Distribution')
plt.show()

# %%
# Bivariate Analysis
# Relationship between Age and Satisfaction
plt.figure(figsize=(10, 6))
sns.boxplot(x='Satisfaction', y='Age', data=df, palette='Set3')
plt.title('Age vs Satisfaction')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_45600\2939402334.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Satisfaction', y='Age', data=df, palette='Set3')

# %%
# Relationship between Flight Distance and Satisfaction
plt.figure(figsize=(10, 6))
sns.boxplot(x='Satisfaction', y='Flight Distance', data=df, palette='Set2')
plt.title('Flight Distance vs Satisfaction')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_45600\1844912632.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Satisfaction', y='Flight Distance', data=df, palette='Set2')

# %%
# Multivariate Analysis
# Pairplot of key variables colored by Satisfaction
sns.pairplot(df[['Age', 'Flight Distance', 'Departure Delay', 'Arrival Delay', 'Satisfaction']], hue='Satisfaction', palette='coolwarm')
plt.title('Multivariate Pairplot')
plt.show()

# %%
# Heatmap showing relationships between Type of Travel, Class, and Satisfaction
plt.figure(figsize=(10, 6))
df_grouped = df.groupby(['Type of Travel', 'Class', 'Satisfaction']).size().unstack()
sns.heatmap(df_grouped, annot=True, cmap='YlGnBu')
plt.title('Satisfaction by Type of Travel and Class')
plt.show()
